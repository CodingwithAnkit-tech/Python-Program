# %%
movies=['War 2','Coolie','Narsimha','Fanstic 4','Saiyaara','Nobody 2','Bring Her Back','Weapons','Avatar fire and ash']
price=[350,300,250,400,900,350,600,500,1200]
print('---------------------WELCOME TO BOOK MY SHOW------------------')
print(movies[0],' - ',price[0])
print(movies[1],' - ',price[1])
print(movies[2],' - ',price[2])
print(movies[3],' - ',price[3])
print(movies[4],' - ',price[4])
print(movies[5],' - ',price[5])
print(movies[6],' - ',price[6])
print(movies[7],' - ',price[7])
print(movies[8],' - ',price[8])
ask=input("Select the movie: ")
if ask==movies[0]:
    ticket=int(input("Enter the number of tickets: "))
    if ticket<=60:
        print(f'Movie name: {ask}')
        print(f'Price: {price[0]}')
        print(f'Tickets: {ticket}')
        print(f'Total price: {price[0]*ticket}')
        print("Thank you for booking the tickets")
        print("------------------Enjoy your show & Day----------------")
        

elif ask==movies[1]:
    ticket=int(input("Enter the number of tickets: "))
    if ticket<=60:
        print(f'Movie name: {ask}')
        print(f'Price: {price[1]}')
        print(f'Tickets: {ticket}')
        print(f'Total price: {price[1]*ticket}')
        print("Thank you for booking the tickets")
        print("------------------Enjoy your show & Day----------------")

elif ask==movies[2]:
    ticket=int(input("Enter the number of tickets: "))
    if ticket<=60:
        
        print(f'Movie name: {ask}')
        print(f'Price: {price[2]}')
        print(f'Tickets: {ticket}')
        print(f'Total price: {price[2]*ticket}')
        print("Thank you for booking the tickets")
        print("------------------Enjoy your show & Day----------------")

elif ask==movies[3]:
    ticket=int(input("Enter the number of tickets: "))
    if ticket<=60:
        print(f'Movie name: {ask}')
        print(f'Price: {price[3]}')
        print(f'Tickets: {ticket}')
        print(f'Total price: {price[3]*ticket}')
        print("Thank you for booking the tickets")
        print("------------------Enjoy your show & Day----------------")

elif ask==movies[4]:
    ticket=int(input("Enter the number of tickets: "))
    if ticket<=60:
        print(f'Movie name: {ask}')
        print(f'Price: {price[4]}')
        print(f'Tickets: {ticket}')
        print(f'Total price: {price[4]*ticket}')
        print("Thank you for booking the tickets")
        print("------------------Enjoy your show & Day----------------")

elif ask==movies[5]:
    ticket=int(input("Enter the number of tickets: "))
    if ticket<=60:
        print(f'Movie name: {ask}')
        print(f'Price: {price[5]}')
        print(f'Tickets: {ticket}')
        print(f'Total price: {price[5]*ticket}')
        print("Thank you for booking the tickets")
        print("------------------Enjoy your show & Day----------------")        

elif ask==movies[6]:
    ticket=int(input("Enter the number of tickets: "))
    if ticket<=60:
        print(f'Movie name: {ask}')
        print(f'Price: {price[6]}')
        print(f'Tickets: {ticket}')
        print(f'Total price: {price[6]*ticket}')
        print("Thank you for booking the tickets")
        print("------------------Enjoy your show & Day----------------")        

elif ask==movies[7]:
    ticket=int(input("Enter the number of tickets: "))
    if ticket<=60:
        print(f'Movie name: {ask}')
        print(f'Price: {price[7]}')
        print(f'Tickets: {ticket}')
        print(f'Total price: {price[7]*ticket}')
        print("Thank you for booking the tickets")
        print("------------------Enjoy Your Show & Day----------------")        

elif ask==movies[8]:
    ticket=int(input("Enter the number of tickets: "))
    if ticket<=60:
        print(f'Movie name: {ask}')
        print(f'Price: {price[8]}')
        print(f'Tickets: {ticket}')
        print(f'Total price: {price[8]*ticket}')
        print("Thank you for booking the tickets")
        print("------------------Enjoy your show & Day----------------")
# Out:
# ---------------------WELCOME TO BOOK MY SHOW------------------
# War 2  -  350
# Coolie  -  300
# Narsimha  -  250
# Fanstic 4  -  400
# Saiyaara  -  900
# Nobody 2  -  350
# Bring Her Back  -  600
# Weapons  -  500
# Avatar fire and ash  -  1200
