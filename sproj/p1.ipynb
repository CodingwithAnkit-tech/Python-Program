# %%
foods=['Pizza','Burger','Pasta','Sandwich','Biryani','Fried Rice','Noodles','Paneer Tikka','Ice Cream']
price=[200,120,150,100,250,180,160,220,90]

print('---------------------WELCOME TO FOODIE RESTAURANT------------------')

# Customer details
name = input("Enter your Name: ")
phone = input("Enter your Phone Number: ")
address = input("Enter your Address: ")

print("Select the food item: ")
print(foods[0],' - ',price[0])
print(foods[1],' - ',price[1])
print(foods[2],' - ',price[2])
print(foods[3],' - ',price[3])
print(foods[4],' - ',price[4])
print(foods[5],' - ',price[5])
print(foods[6],' - ',price[6])
print(foods[7],' - ',price[7])
print(foods[8],' - ',price[8])

ask=input("Select the food item:")

if ask==foods[0]:
    qty=int(input("Enter the quantity: "))
    if qty<=150:
        print("--------- ORDER SUMMARY ---------")
        print(f'Customer Name : {name}')
        print(f'Phone Number  : {phone}')
        print(f'Address       : {address}')
        print(f'Food Item     : {ask}')
        print(f'Price         : {price[0]}')
        print(f'Quantity      : {qty}')
        print(f'Total Price   : {price[0]*qty}')
        print("---------------------------------")
        print("Thank you for your order")
        print("--------------Enjoy your meal & Day--------------")

elif ask==foods[1]:
    qty=int(input("Enter the quantity: "))
    if qty<=150:
        print("--------- ORDER SUMMARY ---------")
        print(f'Customer Name : {name}')
        print(f'Phone Number  : {phone}')
        print(f'Address       : {address}')
        print(f'Food Item     : {ask}')
        print(f'Price         : {price[1]}')
        print(f'Quantity      : {qty}')
        print(f'Total Price   : {price[1]*qty}')
        print("---------------------------------")
        print("Thank you for your order")
        print("--------------Enjoy your meal & Day--------------")

elif ask==foods[2]:
    qty=int(input("Enter the quantity: "))
    if qty<=150:
        print("\n--------- ORDER SUMMARY ---------")
        print(f'Customer Name : {name}')
        print(f'Phone Number  : {phone}')
        print(f'Address       : {address}')
        print(f'Food Item     : {ask}')
        print(f'Price         : {price[2]}')
        print(f'Quantity      : {qty}')
        print(f'Total Price   : {price[2]*qty}')
        print("---------------------------------")
        print("Thank you for your order")
        print("--------------Enjoy your meal & Day--------------")

elif ask==foods[3]:
    qty=int(input("Enter the quantity: "))
    if qty<=150:
        print("--------- ORDER SUMMARY ---------")
        print(f'Customer Name : {name}')
        print(f'Phone Number  : {phone}')
        print(f'Address       : {address}')
        print(f'Food Item     : {ask}')
        print(f'Price         : {price[3]}')
        print(f'Quantity      : {qty}')
        print(f'Total Price   : {price[3]*qty}')
        print("---------------------------------")
        print("Thank you for your order")
        print("--------------Enjoy your meal & Day--------------")

elif ask==foods[4]:
    qty=int(input("Enter the quantity: "))
    if qty<=150:
        print("--------- ORDER SUMMARY ---------")
        print(f'Customer Name : {name}')
        print(f'Phone Number  : {phone}')
        print(f'Address       : {address}')
        print(f'Food Item     : {ask}')
        print(f'Price         : {price[4]}')
        print(f'Quantity      : {qty}')
        print(f'Total Price   : {price[4]*qty}')
        print("---------------------------------")
        print("Thank you for your order")
        print("--------------Enjoy your meal & Day--------------")

elif ask==foods[5]:
    qty=int(input("Enter the quantity: "))
    if qty<=150:
        print("--------- ORDER SUMMARY ---------")
        print(f'Customer Name : {name}')
        print(f'Phone Number  : {phone}')
        print(f'Address       : {address}')
        print(f'Food Item     : {ask}')
        print(f'Price         : {price[5]}')
        print(f'Quantity      : {qty}')
        print(f'Total Price   : {price[5]*qty}')
        print("---------------------------------")
        print("Thank you for your order")
        print("--------------Enjoy your meal & Day--------------")

elif ask==foods[6]:
    qty=int(input("Enter the quantity: "))
    if qty<=150:
        print("--------- ORDER SUMMARY ---------")
        print(f'Customer Name : {name}')
        print(f'Phone Number  : {phone}')
        print(f'Address       : {address}')
        print(f'Food Item     : {ask}')
        print(f'Price         : {price[6]}')
        print(f'Quantity      : {qty}')
        print(f'Total Price   : {price[6]*qty}')
        print("---------------------------------")
        print("Thank you for your order")
        print("--------------Enjoy your meal & Day--------------")

elif ask==foods[7]:
    qty=int(input("Enter the quantity: "))
    if qty<=150:
        print("--------- ORDER SUMMARY ---------")
        print(f'Customer Name : {name}')
        print(f'Phone Number  : {phone}')
        print(f'Address       : {address}')
        print(f'Food Item     : {ask}')
        print(f'Price         : {price[7]}')
        print(f'Quantity      : {qty}')
        print(f'Total Price   : {price[7]*qty}')
        print("---------------------------------")
        print("Thank you for your order")
        print("--------------Enjoy your meal & Day--------------")

elif ask==foods[8]:
    qty=int(input("Enter the quantity: "))
    if qty<=150:
        print("--------- ORDER SUMMARY ---------")
        print(f'Customer Name : {name}')
        print(f'Phone Number  : {phone}')
        print(f'Address       : {address}')
        print(f'Food Item     : {ask}')
        print(f'Price         : {price[8]}')
        print(f'Quantity      : {qty}')
        print(f'Total Price   : {price[8]*qty}')
        print("---------------------------------")
        print("Thank you for your order")
        print("--------------Enjoy your meal & Day--------------")
