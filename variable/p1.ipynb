# %% [markdown]
# # Variable in python
#
# - A variable in python is a symbolic name that is a reference or pointer to an object
# - Variable like a container that you can fill in with different types of data values
#
# - we assign value to a variable using assignment operator
#
# - syntax :
#
# varable = value
# - Example
# greating = "Hello word"
#
# print(greating)

# %%
# variable in python
a = 1 
print(a)

b = 1.24
print(b)

c = 'madhav'   # adding a number to a variable
print(c)

a,b,c = 1,2,3  # assign multiple variable
print(a,b,c)
# Out:
# 1
# 1.24
# madhav
# 1 2 3

# %%
# ways to declare a variable name
MyName = "Ankit"  # pascal case
myName = "Ankit"   # camel case 
myname = "Ankit"    # flat case 
My_name = "Ankit"    # snake case

# %% [markdown]
# # Rules for Python variables:
#
# - A variable name must start with a letter or the underscore character
# - A variable name cannot start with a number
# - A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# - Variable names are case-sensitive (age, Age and AGE are three different variables)
# - A variable name cannot be any of the Python keywords.

# %%
# Example
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

# %% [markdown]
# # Types of Variables in Python
#
# 1️⃣ Local Variable
#
# Defined inside a function
#
# 2️⃣ Global Variable
#
# Defined outside a function

# %%
# Local variable 
def show():
    x = 10   # local variable
    print(x)

show()
# print(x) ❌ error
# Out:
# 10

# %%
# Global variable 
x = 50

def display():
    print(x)

display()
# Out:
# 50
