# %% [markdown]
# # scope of variables==================
# - It defines how for we can acces or modify a variables.
#
# - we can acces globale scope variable also main space variable

# %%
a=10
def main():
    global a
    a +=10
    print("Inside the function space: ",a)
print("All main space :",a)
main()
# Out:
# All main space : 10
# Inside the function space:  20

# %%
# we can not modify the gloable scope variable inside functional space ,in order to do that we have to use the gloable keyword 
a=10
def main():
    global a # the modify the gloable variable inside the function 
    a +=10
    print("Inside the function space: ",a)
print("All main space :",a)
main()
# Out:
# All main space : 10
# Inside the function space:  20

# %%
#  Local scpope---------------------------
# if we decalare a variable inside a function  then it is known as local scope of variable
# we can not access local scope of variable at main space , IT can be access inside the function only.


a=10
def maoin():
    b=20  # Local access 
    print("The values of b :",b)
main()
print(a)
# Out:
# Inside the function space:  20
# 20

# %%
# Enclosed/ Non Local Scope of variable---
 #if we declare a value inside a nested function then it is consider as Enclosed or non local scope of variable

a=10 # Global Scope
def main():
    b=20
    print("The value of b :", b)
    def inner():
        c=30 # Enclosed 
        print("The values of c :",c)
        def core():
           d=50 # Local
           print("The values of d :",d)
main()
# Out:
# The value of b : 20

# %%
# we can acces this encloed var at non local and local.
# if we try to modify the non local variable or encoloed variable in side the local space by default it not possible, in order to do that or  inorder to modify 
# or in order to use non local keyword

a=10
def main():
    b=20
    print("The value of b  :",b)
    def inner():
        print("Inside the local space :", b)
        c=30
    inner()
main()
# Out:
# The value of b  : 20
# Inside the local space : 20

# %%
a=10 # Gloabal scope
def main():
    b=20 #Enclosed 
    print("The value of b  at non_local space :",b)
    def inner():
        nonlocal b
        b  +=15
        print("Inside the local space :", b)
        c=30
    inner()
main()
# Out:
# The value of b  at non_local space : 20
# Inside the local space : 35

# %%
# Buit in scope------------------
#it is an inbuild scope which can be  acceseed any module

import keyword
keyword.kwlist


print(),input(),id()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       4 import keyword
#       5 keyword.kwlist
# ----> 8 print(),input(),id()
#
# TypeError: id() takes exactly one argument (0 given)

# %% [markdown]
# -  what is the difference between between locan space and non local SPACE
# - What is build in space
# - what is the use of global and non local keyword
