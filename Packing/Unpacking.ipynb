# %% [markdown]
# # unpacking---
#
# - it is a process  of extracting the values from a packed structure into seprate variables.
# - Unpacking in Python means extracting values from an iterable (like tuple, list, string, dictionary, set) and assigning them to variables.

# %% [markdown]
# # 🚀 Why Unpacking is Powerful?
#
# Makes code clean and readable
#
# Used in data science
#
# Used in backend frameworks (Django, Flask)
#
# Very common in interviews
#
# Makes Python code more "Pythonic"

# %%
# 
t = (10, 20, 30)
a, b, c = t

print(a, b, c)
# Out:
# 10 20 30

# %%
# List Unpacking
nums = [1, 2, 3]
x, y, z = nums
print(x, y, z)
#Works same as tuple.
# Out:
# 1 2 3

# %%
# Extended Unpacking (* Operator)
# Used when number of variables ≠ number of elements.
a, *b = 1, 2, 3, 4
print(a)
print(b)

#*b collects remaining elements as a list.
# Out:
# 1
# [2, 3, 4]

# %%
# Unpacking in Function Calls (*)

# Used to pass iterable as positional arguments.

def add(a, b, c):
    print(a + b + c)

nums = [1, 2, 3]
add(*nums)
add(1, 2, 3)
# Out:
# 6
# 6

# %%
# Dictionary Unpacking (**)
# ✅ Passing dictionary to function
def greet(name, age):
    print(name, age)

data = {"name": "Ankit", "age": 21}
greet(**data)

#👉 **data unpacks key-value pairs.
# Out:
# Ankit 21

# %%
#Merging Dictionaries
d1 = {"a": 1}
d2 = {"b": 2}

merged = {**d1, **d2}
print(merged)
# Out:
# {'a': 1, 'b': 2}

# %%
# Unpacking in Loops
pairs = [(1, 2), (3, 4)]

for x, y in pairs:
    print(x, y)
# Out:
# 1 2
# 3 4

# %%
#Swapping Variables
a = 5
b = 10

a, b = b, a
print(a, b)
# Out:
# 10 5

# %%
# Returning Multiple Values
def values():
    return 10, 20

x, y = values()
print(x, y)
# Out:
# 10 20

# %%
# Nested Unpacking
data = (1, (2, 3))

a, (b, c) = data
print(a, b, c)
# Out:
# 1 2 3

# %%
#Ignoring Values Using _
a, _, c = (10, 20, 30)
print(a, c)
# Out:
# 10 30

# %% [markdown]
# # Packing vs Unpacking
#
# | Feature | Packing                        | Unpacking                         |
# | ------- | ------------------------------ | --------------------------------- |
# | Meaning | Multiple values → one variable | One iterable → multiple variables |
# | Symbol  | `*args`, `**kwargs`            | `*`, `**`                         |
# | Used in | Function definition            | Function call                     |
