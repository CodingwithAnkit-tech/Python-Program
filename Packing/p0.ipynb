# %% [markdown]
# # Packing-------------
#
# """It is a process of combining or binding or packing multiple values in a single variable
# It use during the transfer of data specially during the function call.
#
# there are two types of packing
#
# 1) single packing
#
# it done in the from of tuple
# upper term tuple and dict we can
#
#
# 2) Double packing
# it is done in the form o dict.get
#
#
# # unpacking---
#
# - it is a process  of extracting the values from a packed structure into seprate varaiblesn

# %%
t1=1,2,3,4,5
print(t1,type(t1))

def single_pack(*args):

    print(args,type(args))
single_pack(10,20,30,40)
# Out:
# (1, 2, 3, 4, 5) <class 'tuple'>
# (10, 20, 30, 40) <class 'tuple'>
